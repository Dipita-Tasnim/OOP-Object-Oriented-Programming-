# %%
# ## Practise:


# class Robot:
#     def __init__(self):  #auto call hobe
#         self.x = 0
#         self.y = 0
#     def say_hello(self): #method-1
#         print(f"Hello! My position is({self.x},{self.y})")
#     def walk(self, x, y):  #method-2
#         self.x = self.x + x
#         self.y = self.y + y

# robot1 = Robot() #class er function call ..bracket e init er bracket er jinish call korte hobe.
# print("First Robot")
# robot1.say_hello()  #method-1 call
# robot1.walk(3, 2)#method-2 call
# robot1.say_hello()  #method-1 call
# robot1.walk(3, 2)#method-2 call
# robot1.say_hello()  #method-1 call

# robot2 = Robot()
# print("\nSecond Robot")
# robot2.walk(5, 10)#method-2 call         #porpor lekhay duita plus kore ekta output ashche.
# robot2.walk(4, 6)#method-2 call
# robot2.say_hello()   #method-1 call
# Out:
# First Robot
# Hello! My position is(0,0)
# Hello! My position is(3,2)
# Hello! My position is(6,4)
#
# Second Robot
# Hello! My position is(9,16)

# %%
-------------------------------------------------------------------------------

# %%
#Task 1

class DataType:
  def __init__(self, nam, valu):
    self.name = nam  # parameter e ja dibo, = er right side eo ta dite hoy. Aar instance
    self.value = valu  # var e restriction ache kina ta driver code theke check korbo.


#Driver code start-
data_type1 = DataType('Integer', 1234)  #class er shathe bracket e kichu thaka mane
                                        # ei argu gulo constractor e set hobe.

print(data_type1.name) #instance variable e restriction.(not constarctor er parameter)
print(data_type1.value)
print('=====================')
data_type2 = DataType('String', 'Hello')
print(data_type2.name)
print(data_type2.value)
print('=====================')
data_type3 = DataType('Float', 4.0)
print(data_type3.name)
print(data_type3.value)
# Out:
# Integer
# 1234
# ...
# String
# Hello
# ...
# Float
# 4.0

# %%
# Task 2(see task 6-another method)

# self er shathe aar kichu likhi nai karon- flower1.name='Rose' eta kono
# arguement mean kore na(bracket diye likhe nai and 12 no. line e bracket
# er bhitor faka rakha hoyeche). eta normally ekta instance variable e value assign
# kora bujhacche.

class Flower:
  def __init__(self):
    pass

flower1 = Flower() # ekhane faka othocho porer line instance variable er reference
                   # value set kora, tahole pass diye dibo.
flower1.name="Rose"
flower1.color="Red"
flower1.num_of_petal=6
print("Name of this flower:", flower1.name)
print("Color of this flower:",flower1.color)
print("Number of petal:",flower1.num_of_petal)
print('=====================')
flower2 = Flower()
flower2.name="Orchid"
flower2.color="Purple"
flower2.num_of_petal=4
print("Name of this flower:",flower2.name)
print("Color of this flower:",flower2.color)
print ("Number of petal:",flower2. num_of_petal)

print(flower1)
print(flower2)
print('they are different')
# Out:
# Name of this flower: Rose
# Color of this flower: Red
# Number of petal: 6
# ...
# Name of this flower: Orchid
# Color of this flower: Purple
# Number of petal: 4
# ...
# they are different

# %%
#task 2 (Not perfect)

# ekhane self er shathe name, color, num_of_petal parameter hishebe raka uchit chilo
# ejonnoi egulor niche yellow hoye ache karon egulo parameter e pacche na. jodio tao
# code thikthak e run hoise..but system ta correct na.

# kintu empty string(comment kore rakhsi) dhore nile code ta correct.

class Flower:
  def __init(self):
    self.name = name
    self.color = color
    self.num_of_petal = num_of_petal

    # self.name = ''
    # self.color = ''
    # self.num_of_petal = ''


  pass
flower1 = Flower()
flower1.name="Rose"
flower1.color="Red"
flower1.num_of_petal=6
print("Name of this flower:", flower1.name)
print("Color of this flower:",flower1.color)
print("Number of petal:",flower1.num_of_petal)
print("=====================")
flower2 = Flower()
flower2.name="Orchid"
flower2.color="Purple"
flower2.num_of_petal=4
print("Name of this flower:",flower2.name)
print("Color of this flower:",flower2.color)
print ("Number of petal:",flower2. num_of_petal)
# Out:
# Name of this flower: Rose
# Color of this flower: Red
# Number of petal: 6
# ...
# Name of this flower: Orchid
# Color of this flower: Purple
# Number of petal: 4

# %%
# Task 2 (or eivabeo kora jay)

class Flower:
  name = 'Rose'
  color = 'Red'
  num_of_petal = 6

flower1 = Flower()
flower1.name="Rose"
flower1.color="Red"
flower1.num_of_petal=6
print("Name of this flower:", flower1.name)
print("Color of this flower:",flower1.color)
print("Number of petal:",flower1.num_of_petal)
print('=====================')
flower2 = Flower()
flower2.name="Orchid"
flower2.color="Purple"
flower2.num_of_petal=4
print("Name of this flower:",flower2.name)
print("Color of this flower:",flower2.color)
print ("Number of petal:",flower2. num_of_petal)
# Out:
# Name of this flower: Rose
# Color of this flower: Red
# Number of petal: 6
# ...
# Name of this flower: Orchid
# Color of this flower: Purple
# Number of petal: 4

# %%
# task 3
class Joker:
  def __init__(self, name, power, is_he_psycho):
    self.name = name
    self.power = power
    self.is_he_psycho = is_he_psycho

j1 = Joker('Heath Ledger', 'Mind Game', False)
print(j1.name)
print(j1.power)
print(j1.is_he_psycho)
print('====================')
j2 = Joker('Joaquin Phoenix', 'Laughing out Loud', True)
print(j2.name)
print(j2.power)
print(j2.is_he_psycho)
print('=====================')
if j1 == j2:
  print('same')
else:
  print('different')
j2.name = 'Heath Ledger'
if j1.name == j2.name:
  print('same')
else:
  print('different')

print('j1 and j2 indicate two different memory location of objects of one class. Now, when we create the first object which is- Joker("Heath Ledger", "Mind Game", False) then this will be assigned to j1. And again when we create the other object which is- Joker("Joaquin Phoenix", "Laughing out Loud", True)then this will be assigned to j2. Here j2 is totally a new object with new memory location. So j1!= j2.')
print('This is the case called pass by value. At the very first the value of j2.name was Joaquin Phoenix. Then when we go through the line which was j2.name = Health Ledger , it means the value of j1.name is assigned to j2.name. And finally when we check the if condition wheather j1.name == j2.name then it should be the same.' )
# Out:
# Heath Ledger
# Mind Game
# False
# ...
# Joaquin Phoenix
# Laughing out Loud
# True
# ...
# different
# same

# %%
# Task 4

class Pokemon:
  def __init__(self, pokemon1_name, pokemon2_name, pokemon1_power, pokemon2_power, damage_rate):
    self.pokemon1_name = pokemon1_name
    self.pokemon2_name = pokemon2_name
    self.pokemon1_power = pokemon1_power
    self.pokemon2_power = pokemon2_power
    self.damage_rate = damage_rate

team_pika = Pokemon('pikachu', 'charmander', 90, 60, 10)
print('=======Team 1=======')
print('Pokemon 1:',team_pika.pokemon1_name,
team_pika.pokemon1_power)
print('Pokemon 2:',team_pika.pokemon2_name,
team_pika.pokemon2_power)
pika_combined_power = (team_pika.pokemon1_power +
team_pika.pokemon2_power) * team_pika.damage_rate
print('Combined Power:', pika_combined_power)

team_bulb = Pokemon('bulbasaur', 'squirtle', 80, 70, 9)
print('=======Team 2=======')
print('Pokemon 1:',team_bulb.pokemon1_name,
team_bulb.pokemon1_power)
print('Pokemon 2:',team_bulb.pokemon2_name,
team_bulb.pokemon2_power)
pika_combined_power = (team_bulb.pokemon1_power +
team_bulb.pokemon2_power) * team_bulb.damage_rate
print('Combined Power:', pika_combined_power)
# Out:
# =======Team 1=======
# Pokemon 1: pikachu 90
# Pokemon 2: charmander 60
# Combined Power: 1500
# =======Team 2=======
# Pokemon 1: bulbasaur 80
# Pokemon 2: squirtle 70
# Combined Power: 1350

# %%
#Task 5

class Player:
  pass

  #OR..
  # def __init__(self):
  #   self.name = ''
  #   self.jersy_number = ''
  #   self.position = ''

player1 = Player()
player1.name = "Ronaldo"
player1.jersy_number = 9
player1.position = "Striker"
print("Name of the Player:", player1.name)
print("Jersey Number of player:", player1.jersy_number)
print("Position of player:", player1.position)
print('===========================')
player2 = Player()
player2.name = "Neuer"
player2.jersy_number = 1
player2.position = "Goal Keeper"
print("Name of the player:", player2.name)
print("Jersey Number of player:", player2.jersy_number)
print("Position of player:", player2.position)
# Out:
# Name of the Player: Ronaldo
# Jersey Number of player: 9
# Position of player: Striker
# ...
# Name of the player: Neuer
# Jersey Number of player: 1
# Position of player: Goal Keeper

# %%
# Task 6

#ekhane task 2 er moto pass dile error dibe karon driver code e
#(first part tay mane print(=====)er aag porjonto.) instance variable e
#kono value set kora nai.

# ekhon kivabe dibo? contructor er parameter e to abar kichu deya jabe na. Tai ami
# def e lekhbo na, normally class declare korei variable e value set korbo.

#ekhane first output er jonno driver code er first part e ache dekhe
#easily chokhe porse, exam e protita output er jonno driver code er protita
#part valo kore dekhte hobe.

class Country:
  def __init__(self):

    self.name = 'Bangladesh'  #constructor er parameter e na thakleo baire icchamoto val set kora jay. shudhu None or khali string deya jabe emon na.
    self.continent = 'Asia'
    self.capital = 'Dhaka'
    self.fifa_ranking = '187'

country = Country() # constructor e kono parameter rakha jabe na.
print('Name:',country.name) # instance variable e value nai..so value set korbo.
print('Continent:',country.continent)
print('Capital:',country.capital)
print('Fifa Ranking:',country.fifa_ranking)
print('===================')
country.name = 'Belgium'
country.continent = 'Europe'
country.capital = 'Brussels'
country.fifa_ranking = 1
print('Name:',country.name)
print('Continent:',country.continent)
print('Capital:',country.capital)
print('Fifa Ranking:',country.fifa_ranking)
# Out:
# Name: Bangladesh
# Continent: Asia
# Capital: Dhaka
# Fifa Ranking: 187
# ...
# Name: Belgium
# Continent: Europe
# Capital: Brussels
# Fifa Ranking: 1

# %%
# Task 6 (Incorrect!!)

#(task 2 er moto pass dile ei task er khetre abar kono value pay na.)

class Country:
  def __init__(self):
    pass
  # name = 'Bangladesh'
  # continent = 'Asia'
  # capital = 'Dhaka'
  # fifa_ranking = '187'

country = Country()
print('Name:',country.name)
print('Continent:',country.continent)
print('Capital:',country.capital)
print('Fifa Ranking:',country.fifa_ranking)
print('===================')
country.name = 'Belgium'
country.continent = 'Europe'
country.capital = 'Brussels'
country.fifa_ranking = 1
print('Name:',country.name)
print('Continent:',country.continent)
print('Capital:',country.capital)
print('Fifa Ranking:',country.fifa_ranking)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-193057a804f4> in <module>
#      12
#      13 country = Country()
# ---> 14 print('Name:',country.name)
#      15 print('Continent:',country.continent)
#      16 print('Capital:',country.capital)
#
# AttributeError: 'Country' object has no attribute 'name'

# %%
# Task 7

class DemonSlayer:
  def __init__(self, name, style, number_of_technique, kill):
    self.name = name
    self.style = style
    self.number_of_technique = number_of_technique
    self.kill = kill

tanjiro = DemonSlayer("Tanjiro", "Water Breathing", 10, 10)
print('Name:',tanjiro.name)
print('Fighting Style:',tanjiro.style)
print(f'Knows {tanjiro.number_of_technique} technique(s) and has killed {tanjiro.kill} demon(s)')
print('===================')
zenitsu = DemonSlayer("Zenitsu", "Thunder Breathing", 1, 4)
print('Name:',zenitsu.name)
print('Fighting Style:',zenitsu.style)
print(f'Knows {zenitsu.number_of_technique} technique(s) and has killed {zenitsu.kill} demon(s)')
print('===================')
inosuke = DemonSlayer("Inosuke", "Beast Breathing", 5, 7)
print('Name:',inosuke.name)
print('Fighting Style:',inosuke.style)
print(f'Knows {inosuke.number_of_technique} technique(s) and has killed {inosuke.kill} demon(s)')
print('===================')
print(f'{tanjiro.name}, {zenitsu.name}, {inosuke.name} knows total {tanjiro.number_of_technique + zenitsu.number_of_technique + inosuke.number_of_technique} techniques')
print(f'They have killed total {tanjiro.kill + zenitsu.kill + inosuke.kill} demons')
# Out:
# Name: Tanjiro
# Fighting Style: Water Breathing
# Knows 10 technique(s) and has killed 10 demon(s)
# ...
# Name: Zenitsu
# Fighting Style: Thunder Breathing
# Knows 1 technique(s) and has killed 4 demon(s)
# ...
# Name: Inosuke
# Fighting Style: Beast Breathing
# Knows 5 technique(s) and has killed 7 demon(s)
# ...
# Tanjiro, Zenitsu, Inosuke knows total 16 techniques
# They have killed total 21 demons

# %%
# Task 8

class box:
  def __init__(self, lst):
    self.height = lst[0]
    self.width = lst[1]
    self.breadth = lst[2]

    volume = self.height * self.width * self.breadth

    print('Creating a Box!')
    print(f'Volume of the box is {volume} cubic units.')


print("Box 1")
b1 = box([10,10,10])
print("=========================")
print("Height:", b1.height)
print("Width:", b1.width)
print("Breadth:", b1.breadth)
print("-------------------------")
print("Box 2")
b2 = box((30,10,10))
print("=========================")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
b2.height = 300
print("Updating Box 2!")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
print("-------------------------")
print("Box 3")
b3 = b2
print("Height:", b3.height)
print("Width:", b3.width)
print("Breadth:", b3.breadth)
# Out:
# Box 1
# Creating a Box!
# Volume of the box is 1000 cubic units.
# ...
# Height: 10
# Width: 10
# Breadth: 10
# -------------------------
# Box 2
# Creating a Box!
# Volume of the box is 3000 cubic units.
# ...
# Height: 30
# Width: 10
# Breadth: 10
# Updating Box 2!
# Height: 300
# Width: 10
# Breadth: 10
# -------------------------
# Box 3
# Height: 300
# Width: 10
# Breadth: 10

# %%
# Task 9

class buttons:
  def __init__(self, word, spaces, border):
    self.word = word
    self.spaces = spaces
    self.border = border
    chr = spaces * 2 + len(word) + 2
    print(self.word,'Button Specifications:')
    print('Button name:',self.word)
    no = 1 + len(self.word) + self.spaces * 2 + 1
    print(f'Number of the border characters for the top and the bottom:{chr}')
    print('Number of spaces between the left side border and the first character of the button name:',self.spaces)
    print('Number of spaces between the right side border and the last character of the button name:',self.spaces)
    print('Characters representing the borders:',self.border)
    print()
    print(self.border*no)
    print(self.border + ' ' * self.spaces + self.word + ' ' * self.spaces + self.border)
    print(self.border * no)

word = "CANCEL"
spaces = 10
border = 'x'
b1 = buttons(word, spaces, border)
print("=======================================================")
b2 = buttons("Notify",3, '!')
print("=======================================================")
b3 = buttons('SAVE PROGRESS', 5, '$')
# Out:
# CANCEL Button Specifications:
# Button name: CANCEL
# Number of the border characters for the top and the bottom:28
# Number of spaces between the left side border and the first character of the button name: 10
# Number of spaces between the right side border and the last character of the button name: 10
# Characters representing the borders: x
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxx
# x          CANCEL          x
# xxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ...
# Notify Button Specifications:
# Button name: Notify
# Number of the border characters for the top and the bottom:14
# Number of spaces between the left side border and the first character of the button name: 3
# Number of spaces between the right side border and the last character of the button name: 3
# Characters representing the borders: !
#
# !!!!!!!!!!!!!!
# !   Notify   !
# !!!!!!!!!!!!!!
# ...
# SAVE PROGRESS Button Specifications:
# Button name: SAVE PROGRESS
# Number of the border characters for the top and the bottom:25
# ...

# %%
# Task 10
class Wadiya():
  def __init__(self):
    self.name = 'Aladeen'
    self.designation = 'President Prime Minister Admiral General'
    self.num_of_wife = 100
    self.dictator = True

wadiya1 = Wadiya()
print('Part 1:')
print('Name of President:',wadiya1.name)
print('Designation:',wadiya1.designation)
print('Number of wife:',wadiya1.num_of_wife)
print('Is he/she a dictator:',wadiya1.dictator)

wadiya2 = Wadiya() #ekhane second part output er jonno object wadiya2 set korsi.
print('Part 2:')   # aager ta mane wadiya1 diye korleo kono problem hoto na.
                   # karon kono method er o jhamela nai, ekta class er under e
                   # just ekta initial method e eta te ache.
print('Name of President:',wadiya2.name)
wadiya2.designation = 'President'
print('Designation:',wadiya2.designation)
wadiya2.num_of_wife = 1
print('Number of wife:',wadiya2.num_of_wife)
wadiya2.dictator = False
print('Is he/she a dictator:',wadiya2.dictator)

print('previous information lost')
# Out:
# Part 1:
# Name of President: Aladeen
# Designation: President Prime Minister Admiral General
# Number of wife: 100
# Is he/she a dictator: True
# Part 2:
# Name of President: Donald Trump
# Designation: President
# Number of wife: 1
# Is he/she a dictator: False
# previous information lost

# %%
#Task 11 (TRACING)

class Human:
  def __init__(self):
    self.age = 0
    self.height = 0.0

h1 = Human()
h2 = Human()
h1.age = 21
h1.height = 5.5
print(h1.age)
print(h1.height)
h2.height = h1.height - 3
print(h2.height)
h2.age = h1.age
h1.age += h1.age
print(h1.age)
h2 = h1  ## Ekhon theke shob h1 er.
print(h2.age)
print(h2.height)
h1.age += h1.age
h2.height += h2.height
print(h1.age)
print(h1.height)
h2.age += h2.age
h1.age = h2.age
print(h2.age)
# Out:
# 21
# 5.5
# 2.5
# 42
# 42
# 5.5
# 84
# 11.0
# 168

# %%
#Task 12 (TRACING)

class Student:
  def __init__(self):
    self.name = None
    self.cgpa = 0.0
s1 = Student()
s2 = Student()
s3 = None
s1.name = "Student One"
s1.cgpa = 2.3
s3 = s1
s2.name = "Student Two"
s2.cgpa = s3.cgpa + 1
s3.name = "New Student"
print(s1.name)
print(s2.name)
print(s3.name)
print(s1.cgpa)
print(s2.cgpa)
print(s3.cgpa)
s3 = s2
s1.name = "old student"
s2.name = "older student"
s3.name = "oldest student"
s2.cgpa = s1.cgpa - s3.cgpa + 4.5
print(s1.name)
print(s2.name)
print(s3.name)
print(s1.cgpa)
print(s2.cgpa)
print(s3.cgpa)
# Out:
# New Student
# Student Two
# New Student
# 2.3
# 3.3
# 2.3
# old student
# oldest student
# oldest student
# 2.3
# 3.5
# 3.5

# %%
#Task 13 (TRACING)

class Ninja:
  def __init__(self):
    self.rank = 0
    self.stamina = 0.0

naruto = Ninja()
yellow_flash = Ninja()
naruto.rank = 1
naruto.stamina = 95.0
print(naruto.rank)
print(naruto.stamina)
yellow_flash.stamina = naruto.stamina - 2
print(yellow_flash.stamina)
yellow_flash.rank += (naruto.rank + 1)
print(yellow_flash.rank)
minato = yellow_flash
print(minato.rank)
print(minato.stamina)
naruto.rank = minato.rank - 1
naruto.stamina = yellow_flash.stamina + 3
print(naruto.rank)
print(naruto.stamina)
naruto.rank = -(-naruto.rank)
yellow_flash.stamina = -(-minato.stamina)
print(naruto.rank)
print(minato.stamina)
# Out:
# 1
# 95.0
# 93.0
# 2
# 2
# 93.0
# 1
# 96.0
# 1
# 93.0
